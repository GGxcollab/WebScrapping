# %%
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# #from webdriver_manager.chrome import ChromeDriverManager
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# import pyautogui
# import time

# #servico = Service(ChromeDriverManager().install())
# # Criar o navegador
# nav = webdriver.Chrome()

# # Entrar no navegador 
# arquivo = 'https://www.virustotal.com/'
# nav.get(arquivo)
# # esperar o site carregar
# time.sleep(5)

# %%
import pyautogui
import time

# abrir o Chrome
pyautogui.PAUSE = 0.5

pyautogui.press("win")
pyautogui.write("chrome")
pyautogui.press("enter")

time.sleep(10)

# Clica na area de pesquisa
pyautogui.click(x=-1676, y=57)

# entrar no link
link = "https://www.virustotal.com/"

pyautogui.write(link)
pyautogui.press("enter")

# esperar o site carregar
time.sleep(4)

# %%
import pandas as pd
# Carrega o txt com o Search a ser procurado
search_hashs = pd.read_csv('pags_pesquisa1.txt')
display(search_hashs)
# Out:
#                                        Search_Paginas
# 0   c6c5a95fa369d1a112074024544a8f3b4928c960a0869f...
# 1   fc8fb70477a8294780bbdeb62c1139db9f3b3e3f14e216...
# 2   34710359b5e86484e8595c997faa2a5e161d90aae8b488...
# 3   46a53b4a8fc3155eb0e8b53b1df031a8c6cc9e9a2d79cc...
# 4   c6c5a95fa369d1a112074024544a8f3b4928c960a0869f...
# 5   0e9d70436bc6f0924ca4d2cda6ad1e6b9431c76993a699...
# 6   586c67b3b9738fbb6bcdb3b2a7e0faaab02a696e234439...
# 7   01cd21ffa0e942980d79dffd8b64a0d39775dae2aa7aba...
# 8   0feb16e01168b617cc4b301c414e4e6bff741962f1a25f...
# 9   a8c4f1ad5cdccbaf02ee38353bfba3b8aa61fd039d7ca8...
# 10  3a0c9be1affbdbbd7731ea975be3a3d4d870015288ae19...
# 11  1abf9a2c9557e8aa9bf3f4859a2fef18bbf53ded79ce95...

# %%
count_num = 1
#count_pag = 1

for hash in search_hashs['Search_Paginas']:
    print(hash)

    count_num = count_num + 1  #(3)

    # Aperta no Button de Search da página
    pyautogui.click(x=-742, y=395, button="right")                
    #time.sleep(2)
    # Abre uma nova guia
    pyautogui.click(x=-709, y=406, button="left")
    time.sleep(2)


    # Passa para a nova guia
    pyautogui.hotkey('ctrl', "pgup")
    print(count_num)
    pyautogui.write(f"{hash}")
    pyautogui.press("enter")
    time.sleep(4)

    # Volta para a aba de pesquisa e pesquisa outro hash
    pyautogui.hotkey('ctrl', '1')


    # pyautogui.click(x=921, y=433, button="right")                
    # time.sleep(2) f'{count_num}'

    # count_pag = count_pag + 1
    # # Abre uma nova guia
    # pyautogui.click(x=944, y=447, button="left")
    # time.sleep(2)

    # pyautogui.hotkey('ctrl', f'{count_pag}')
    # pyautogui.write("fc8fb70477a8294780bbdeb62c1139db9f3b3e3f14e2163f033e1d043192a140")
    # pyautogui.press("enter")

# if pyautogui.close
# Escreve o que você quer pesquisar na caixa de texto  
# pyautogui.click(x=497, y=684)
# pyautogui.write("fc8fb70477a8294780bbdeb62c1139db9f3b3e3f14e2163f033e1d043192a140")
# pyautogui.press("enter")
# Out:
# c6c5a95fa369d1a112074024544a8f3b4928c960a0869f95cde6af70193b9600
# 2
# fc8fb70477a8294780bbdeb62c1139db9f3b3e3f14e2163f033e1d043192a140
# 3
# 34710359b5e86484e8595c997faa2a5e161d90aae8b488d67529acccbd1bfa12
# 4
# 46a53b4a8fc3155eb0e8b53b1df031a8c6cc9e9a2d79cc6eb8dcf40de804a7f6
# 5
# c6c5a95fa369d1a112074024544a8f3b4928c960a0869f95cde6af70193b9600
# 6
# 0e9d70436bc6f0924ca4d2cda6ad1e6b9431c76993a69978d4a0c866d8a78880
# 7
# 586c67b3b9738fbb6bcdb3b2a7e0faaab02a696e2344391b798bc85c8bdc1bf0
# 8
# 01cd21ffa0e942980d79dffd8b64a0d39775dae2aa7aba02c3862452088acc91
# 9
# 0feb16e01168b617cc4b301c414e4e6bff741962f1a25f1a72813aa9d2e1eb5c
# 10
# a8c4f1ad5cdccbaf02ee38353bfba3b8aa61fd039d7ca8d8eae15730cce0005e
# 11
# 3a0c9be1affbdbbd7731ea975be3a3d4d870015288ae19603f0381ab658d203d
# 12
# 1abf9a2c9557e8aa9bf3f4859a2fef18bbf53ded79ce956dcf299b90b9ec9d06
# 13

# %%
# # pegar os resultados
# while len(nav.find_elements(By.XPATH, '//*[@id="view-container"]/home-view//div/div/div/div[1]/div[1]/div/a')) < 1:
#     time.sleep(1)

#nav.find_element(By.XPATH,'//*[@id="view-container"]/home-view//div/div/div/div[1]/div[1]/ul/li[3]/a').click()

# %%
# Clica no Search para pesquisar
#pyautogui.click(x=891, y=449)
#nav.find_element(By.XPATH,'//*[@id="view-container"]/home-view//div/div/div/div[1]/div[1]/ul/li[2]/a').click()
#search = nav.find_element(By.LINK_TEXT, "Search").click()

# rodar entre a tabelas e abrir pags com as urls

# %%
# lista_elementos = nav.find_elements(By.CLASS_NAME, 'a.py-4 nav-link   ')
# for elemento in lista_elementos:
#     print(elemento)
#     if "Search" in elemento:
#         elemento.click()
#         break

# %%
#
